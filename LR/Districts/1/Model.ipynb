# %% [markdown]
# <a href="https://colab.research.google.com/github/MattIzon/16010269_DataAnalytics/blob/main/LR/Districts/1/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model Template

# %%
# Set-up
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def normalise(df, column_list):
  # Normalises df columns in column_list returning a dictionary of column_name: (min_value, max_value) that can be used to recover the original values
  params = dict()

  for col in column_list:
    min = df[col].min()
    max = df[col].max()
    params[col] = (min, max)
    df[col] = (df[col] - min) / (max - min)

  return params


def normalise_w_params(df, params, column_list):
  # Normalises df columns using the provided params
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] - min) / (max - min)


def denormalise(df, params, column_list):
  # Uses the params dictionary produced during normalisation and a list of columns to recover their original values
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] * (max-min)) + min


def flat_list(nested_list):
  return [value for sublist in nested_list for value in sublist]

# %%
generic = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/1/generic_set_district1.0.csv')

# %% [markdown]
# Model Specific Code goes here

# %%
generic.corr()['crime_count']
# Out:
# index                   0.163109
# day_of_week            -0.212150
# district                     NaN
# crime_count             1.000000
# mo                      0.162114
# temp                    0.260212
# dewp                    0.261973
# slp                    -0.144656
# stp                    -0.011257
# visib                   0.087582
# wdsp                   -0.081384
# mxpsd                  -0.042748
# gust                   -0.036088
# max                     0.247429
# min                     0.271675
# prcp                    0.037959
# sndp                   -0.228342
# fog                    -0.047208
# rain_drizzle            0.059003
# snow_ice_pellets       -0.136210
# hail                         NaN
# thunder                 0.069048
# tornado_funnel_cloud         NaN
# Name: crime_count, dtype: float64

# %%
columns = ['day_of_week', 'temp', 'sndp', 'crime_count']
data = generic[columns]
scale_params = normalise(data, columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Seperate train / eval predictors / targets
qty_predictors = 3
qty_targets = 1
train_size = int(len(data)*0.8)

train_predictors = data.iloc[:train_size,0:qty_predictors]
train_targets = data.iloc[:train_size,qty_predictors]

eval_predictors = data.iloc[train_size:,0:qty_predictors]
eval_targets = data.iloc[train_size:,qty_predictors]

# %%
# Design model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(qty_targets, input_shape=[qty_predictors]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.01))

# %%
# View model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
history = model.fit(train_predictors, train_targets, epochs=250)
# Out:
# Epoch 1/250
# 44/44 [==============================] - 1s 2ms/step - loss: 0.2666
# Epoch 2/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.1007
# Epoch 3/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0789
# Epoch 4/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0625
# Epoch 5/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0513
# Epoch 6/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0444
# Epoch 7/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0405
# Epoch 8/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 9/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 10/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 11/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0352
# Epoch 12/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 13/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0343
# Epoch 14/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 15/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0338
# Epoch 16/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0336
# Epoch 17/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 18/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 19/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 20/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 21/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 22/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 23/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 24/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 25/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 26/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 27/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 28/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 29/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 30/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 31/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 32/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 33/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 34/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 35/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 36/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 37/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 38/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 39/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 40/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 41/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 42/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 43/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 44/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 45/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 46/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 47/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 48/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 49/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 50/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 51/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 52/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 53/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 54/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 55/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 56/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 57/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 58/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 59/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 60/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 61/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 62/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 63/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 64/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 65/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 66/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 67/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 68/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 69/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 70/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 71/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 72/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 73/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 74/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 75/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 76/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 77/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 78/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 79/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 80/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 81/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0334
# Epoch 82/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 83/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 84/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 85/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 86/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 87/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 88/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 89/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 90/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 91/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 92/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 93/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 94/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 95/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 96/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 97/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 98/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0334
# Epoch 99/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 100/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 101/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 102/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 103/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 104/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 105/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 106/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 107/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 108/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 109/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 110/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 111/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 112/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 113/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 114/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 115/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 116/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 117/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 118/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 119/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 120/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 121/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 122/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 123/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 124/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 125/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 126/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 127/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 128/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 129/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 130/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 131/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 132/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 133/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 134/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 135/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 136/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 137/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 138/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 139/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 140/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 141/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 142/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 143/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 144/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 145/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0327
# Epoch 146/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 147/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 148/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 149/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 150/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 151/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 152/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 153/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 154/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 155/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 156/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 157/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 158/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 159/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 160/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 161/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 162/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 163/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 164/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 165/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 166/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 167/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 168/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 169/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 170/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 171/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 172/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 173/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 174/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 175/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 176/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 177/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 178/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 179/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 180/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 181/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 182/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 183/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 184/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 185/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 186/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 187/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 188/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 189/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 190/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 191/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 192/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 193/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 194/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 195/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 196/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 197/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 198/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 199/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0336
# Epoch 200/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 201/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 202/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 203/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 204/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 205/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 206/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 207/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0334
# Epoch 208/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 209/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 210/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 211/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 212/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 213/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 214/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 215/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 216/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 217/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 218/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 219/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 220/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 221/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 222/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 223/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 224/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 225/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 226/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 227/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 228/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 229/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 230/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 231/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 232/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 233/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 234/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 235/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 236/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 237/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 238/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0335
# Epoch 239/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 240/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0333
# Epoch 241/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 242/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 243/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 244/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 245/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 246/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0330
# Epoch 247/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 248/250
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0328
# Epoch 249/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 250/250
# 44/44 [==============================] - 0s 1ms/step - loss: 0.0331

# %%
# View training history
plt.plot(history.history['loss'])

# %%
# Test model
eval_predictions = flat_list(model.predict(eval_predictors))

# %%
# Analyse model quality vs mean 
rmse = np.sqrt(np.mean((eval_targets.values - eval_predictions)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));

avg = np.mean(train_targets)

rmse = np.sqrt(np.mean((eval_targets.values - avg)**2))
print('Using the training data mean of {0} would have has resulted in a RMSE of {1}'.format(avg, rmse));
# Out:
# LinearRegression has RMSE of 0.1914878564590348
# Using the training data mean of 0.5800811688311688 would have has resulted in a RMSE of 0.2056886171602519

# %%
# Testing

test = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/1/test_set_district1.0.csv')
test_predictors = test[columns[0:qty_predictors]]
normalise_w_params(test_predictors, scale_params, columns[0:qty_predictors])

test_predictions = pd.DataFrame(flat_list(model.predict(test_predictors)), columns=['crime_count'])
denormalise(test_predictions, scale_params, ['crime_count'])
test_targets = test[columns[qty_predictors]]

results = pd.DataFrame()
results['predicted'] = test_predictions
results['actual'] = test_targets
results['error_squared'] = (results['predicted'] - results['actual']) ** 2
print(results)

print('The RMSE on the 5 test values is {}.'.format(np.sqrt(np.mean(results.error_squared))))
print()
# Out:
#    predicted  actual  error_squared
# 0  42.465508      42       0.216697
# 1  40.157310      36      17.283230
# 2  38.677856      44      28.325212
# 3  39.296844      30      86.431317
# 4  32.481155      22     109.854618
# The RMSE on the 5 test values is 6.958607267073942.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
