# %% [markdown]
# <a href="https://colab.research.google.com/github/MattIzon/16010269_DataAnalytics/blob/main/LR/Districts/2/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model District 2
#
# Predictors:
# *   day_of_week
# *   temp
# *   sndp
# *   snow_ice_pellets

# %%
# Set-up
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def normalise(df, column_list):
  # Normalises df columns in column_list returning a dictionary of column_name: (min_value, max_value) that can be used to recover the original values
  params = dict()

  for col in column_list:
    min = df[col].min()
    max = df[col].max()
    params[col] = (min, max)
    df[col] = (df[col] - min) / (max - min)

  return params


def normalise_w_params(df, params, column_list):
  # Normalises df columns using the provided params
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] - min) / (max - min)


def denormalise(df, params, column_list):
  # Uses the params dictionary produced during normalisation and a list of columns to recover their original values
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] * (max-min)) + min


def flat_list(nested_list):
  return [value for sublist in nested_list for value in sublist]

# %%
generic = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/2/generic_set_district2.0.csv')

# %% [markdown]
# Model Specific Code goes here

# %%
generic.corr()['crime_count']
# Out:
# index                   0.169299
# day_of_week            -0.126858
# district                     NaN
# crime_count             1.000000
# mo                      0.172143
# temp                    0.425616
# dewp                    0.409429
# slp                    -0.189275
# stp                     0.098990
# visib                   0.145336
# wdsp                   -0.098569
# mxpsd                  -0.047423
# gust                   -0.020300
# max                     0.421618
# min                     0.424226
# prcp                    0.047883
# sndp                   -0.267285
# fog                    -0.057743
# rain_drizzle            0.031246
# snow_ice_pellets       -0.235919
# hail                         NaN
# thunder                 0.094475
# tornado_funnel_cloud         NaN
# Name: crime_count, dtype: float64

# %%
columns = ['day_of_week', 'temp', 'sndp', 'snow_ice_pellets', 'crime_count']
data = generic[columns]
scale_params = normalise(data, columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Seperate train / eval predictors / targets
qty_predictors = 4
qty_targets = 1
train_size = int(len(data)*0.8)

train_predictors = data.iloc[:train_size,0:qty_predictors]
train_targets = data.iloc[:train_size,qty_predictors]

eval_predictors = data.iloc[train_size:,0:qty_predictors]
eval_targets = data.iloc[train_size:,qty_predictors]

# %%
# Design model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(qty_targets, input_shape=[qty_predictors]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.01))

# %%
# View model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
history = model.fit(train_predictors, train_targets, epochs=250)
# Out:
# Epoch 1/250
# 46/46 [==============================] - 1s 1ms/step - loss: 0.7572
# Epoch 2/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1045
# Epoch 3/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0402
# Epoch 4/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0351
# Epoch 5/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 6/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0311
# Epoch 7/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0298
# Epoch 8/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0289
# Epoch 9/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0283
# Epoch 10/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 11/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 12/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 13/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 14/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 15/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0260
# Epoch 16/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 17/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0255
# Epoch 18/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 19/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 20/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 21/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0246
# Epoch 22/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0245
# Epoch 23/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0243
# Epoch 24/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0242
# Epoch 25/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0241
# Epoch 26/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 27/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 28/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 29/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 30/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 31/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 32/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 33/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 34/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 35/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 36/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 37/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 38/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 39/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 40/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 41/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 42/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 43/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 44/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 45/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 46/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 47/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 48/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 49/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 50/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 51/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 52/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 53/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 54/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 55/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 56/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 57/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 58/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 59/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 60/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 61/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 62/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 63/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 64/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 65/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 66/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 67/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 68/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 69/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 70/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 71/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 72/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 73/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0241
# Epoch 74/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 75/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 76/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 77/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 78/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 79/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 80/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 81/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 82/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 83/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 84/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 85/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 86/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 87/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 88/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 89/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 90/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 91/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 92/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 93/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0242
# Epoch 94/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 95/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 96/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 97/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 98/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 99/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 100/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 101/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 102/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 103/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 104/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 105/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 106/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 107/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 108/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 109/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 110/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 111/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 112/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 113/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 114/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 115/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 116/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 117/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 118/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 119/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 120/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 121/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 122/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 123/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 124/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 125/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 126/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 127/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 128/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 129/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 130/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 131/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 132/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 133/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 134/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 135/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 136/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 137/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 138/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 139/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 140/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 141/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0241
# Epoch 142/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 143/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 144/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 145/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 146/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 147/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 148/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 149/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 150/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 151/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 152/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 153/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0241
# Epoch 154/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 155/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 156/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 157/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 158/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 159/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 160/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 161/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 162/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 163/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 164/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 165/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 166/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 167/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 168/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 169/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 170/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 171/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 172/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 173/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 174/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 175/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 176/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 177/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 178/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 179/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 180/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 181/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 182/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 183/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 184/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 185/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 186/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 187/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 188/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 189/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 190/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 191/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 192/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 193/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0234
# Epoch 194/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 195/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 196/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 197/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 198/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 199/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0243
# Epoch 200/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 201/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 202/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 203/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 204/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 205/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 206/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 207/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 208/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 209/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 210/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 211/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 212/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 213/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 214/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 215/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 216/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 217/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 218/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 219/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 220/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 221/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 222/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0236
# Epoch 223/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 224/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 225/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 226/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 227/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 228/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0241
# Epoch 229/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 230/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 231/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 232/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 233/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 234/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0234
# Epoch 235/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 236/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 237/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 238/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 239/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 240/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0238
# Epoch 241/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 242/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 243/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236
# Epoch 244/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 245/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 246/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 247/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 248/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0235
# Epoch 249/250
# 46/46 [==============================] - 0s 2ms/step - loss: 0.0239
# Epoch 250/250
# 46/46 [==============================] - 0s 1ms/step - loss: 0.0236

# %%
# View training history
plt.plot(history.history['loss'])

# %%
# Test model
eval_predictions = flat_list(model.predict(eval_predictors))

# %%
# Analyse model quality vs mean 
rmse = np.sqrt(np.mean((eval_targets.values - eval_predictions)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));

avg = np.mean(train_targets)

rmse = np.sqrt(np.mean((eval_targets.values - avg)**2))
print('Using the training data mean of {0} would have has resulted in a RMSE of {1}'.format(avg, rmse));
# Out:
# LinearRegression has RMSE of 0.15107626434464813
# Using the training data mean of 0.48297446989807624 would have has resulted in a RMSE of 0.16937610932156033

# %%
# Testing

test = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/1/test_set_district1.0.csv')
test_predictors = test[columns[0:qty_predictors]]
normalise_w_params(test_predictors, scale_params, columns[0:qty_predictors])

test_predictions = pd.DataFrame(flat_list(model.predict(test_predictors)), columns=['crime_count'])
denormalise(test_predictions, scale_params, ['crime_count'])
test_targets = test[columns[qty_predictors]]

results = pd.DataFrame()
results['predicted'] = test_predictions
results['actual'] = test_targets
results['error_squared'] = (results['predicted'] - results['actual']) ** 2
print(results)

print('The RMSE on the 5 test values is {}.'.format(np.sqrt(np.mean(results.error_squared))))
print()
# Out:
#    predicted  actual  error_squared
# 0  35.644608      42      40.391013
# 1  34.691059      36       1.713326
# 2  30.526548      44     181.533898
# 3  33.015945      30       9.095927
# 4  28.121386      22      37.471361
# The RMSE on the 5 test values is 7.35126555276583.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
