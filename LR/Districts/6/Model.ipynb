# %% [markdown]
# <a href="https://colab.research.google.com/github/MattIzon/16010269_DataAnalytics/blob/main/LR/Districts/6/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model District 6
#
# Predictors:
# *   day_of_week
# *   temp
# *   sndp
# *   snow_ice_pellets

# %%
# Set-up
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def normalise(df, column_list):
  # Normalises df columns in column_list returning a dictionary of column_name: (min_value, max_value) that can be used to recover the original values
  params = dict()

  for col in column_list:
    min = df[col].min()
    max = df[col].max()
    params[col] = (min, max)
    df[col] = (df[col] - min) / (max - min)

  return params


def normalise_w_params(df, params, column_list):
  # Normalises df columns using the provided params
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] - min) / (max - min)


def denormalise(df, params, column_list):
  # Uses the params dictionary produced during normalisation and a list of columns to recover their original values
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] * (max-min)) + min


def flat_list(nested_list):
  return [value for sublist in nested_list for value in sublist]

# %%
district = 6
generic = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/{0}/generic_set_district{0}.0.csv'.format(district))

# %% [markdown]
# Model Specific Code goes here

# %%
generic.corr()['crime_count']
# Out:
# index                   0.139603
# day_of_week            -0.040105
# district                     NaN
# crime_count             1.000000
# mo                      0.140742
# temp                    0.431238
# dewp                    0.403059
# slp                    -0.202513
# stp                     0.066892
# visib                   0.171735
# wdsp                   -0.146057
# mxpsd                  -0.080719
# gust                   -0.061241
# max                     0.430450
# min                     0.415769
# prcp                    0.012505
# sndp                   -0.276815
# fog                    -0.081568
# rain_drizzle            0.019650
# snow_ice_pellets       -0.310225
# hail                         NaN
# thunder                 0.074557
# tornado_funnel_cloud         NaN
# Name: crime_count, dtype: float64

# %%
columns = ['day_of_week', 'temp', 'sndp', 'snow_ice_pellets', 'crime_count']
data = generic[columns]
scale_params = normalise(data, columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Seperate train / eval predictors / targets
qty_predictors = 4
qty_targets = 1
train_size = int(len(data)*0.8)

train_predictors = data.iloc[:train_size,0:qty_predictors]
train_targets = data.iloc[:train_size,qty_predictors]

eval_predictors = data.iloc[train_size:,0:qty_predictors]
eval_targets = data.iloc[train_size:,qty_predictors]

# %%
# Design model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(qty_targets, input_shape=[qty_predictors]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.01))

# %%
# View model
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
history = model.fit(train_predictors, train_targets, epochs=250)
# Out:
# Epoch 1/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.2662
# Epoch 2/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0743
# Epoch 3/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0511
# Epoch 4/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0386
# Epoch 5/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 6/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0286
# Epoch 7/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 8/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 9/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 10/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 11/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 12/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 13/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 14/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 15/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 16/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 17/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 18/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 19/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 20/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 21/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 22/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 23/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 24/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 25/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 26/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 27/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 28/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 29/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 30/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 31/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 32/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 33/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 34/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 35/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 36/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 37/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 38/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 39/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 40/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 41/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 42/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 43/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 44/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 45/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 46/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 47/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 48/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 49/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 50/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 51/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 52/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 53/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 54/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 55/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 56/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 57/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 58/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 59/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 60/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 61/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 62/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 63/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 64/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 65/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 66/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 67/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 68/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 69/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 70/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 71/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 72/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 73/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 74/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 75/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 76/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 77/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 78/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 79/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 80/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 81/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 82/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 83/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 84/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 85/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 86/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 87/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 88/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 89/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 90/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 91/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 92/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 93/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 94/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 95/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 96/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 97/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0271
# Epoch 98/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 99/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 100/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 101/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 102/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 103/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 104/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 105/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 106/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 107/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 108/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 109/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 110/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 111/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 112/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 113/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 114/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 115/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 116/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 117/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 118/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 119/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 120/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 121/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 122/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 123/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 124/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 125/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 126/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 127/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 128/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0270
# Epoch 129/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 130/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 131/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 132/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 133/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 134/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 135/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 136/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 137/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 138/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 139/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 140/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 141/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 142/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 143/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 144/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 145/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 146/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 147/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 148/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 149/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 150/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 151/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 152/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 153/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 154/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 155/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 156/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 157/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 158/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 159/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 160/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 161/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 162/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 163/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 164/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 165/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 166/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 167/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 168/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 169/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0270
# Epoch 170/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 171/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 172/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 173/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 174/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 175/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 176/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 177/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 178/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 179/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 180/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 181/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 182/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 183/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 184/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 185/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 186/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 187/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 188/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 189/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 190/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 191/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 192/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 193/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 194/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 195/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 196/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 197/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 198/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 199/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 200/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 201/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 202/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 203/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 204/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 205/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 206/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 207/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 208/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 209/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 210/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 211/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 212/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 213/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0276
# Epoch 214/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 215/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 216/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 217/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 218/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 219/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 220/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 221/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 222/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 223/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 224/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 225/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 226/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 227/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 228/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 229/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 230/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 231/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 232/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 233/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 234/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 235/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 236/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 237/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0263
# Epoch 238/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 239/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 240/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0272
# Epoch 241/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0265
# Epoch 242/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 243/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 244/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0266
# Epoch 245/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 246/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0268
# Epoch 247/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0264
# Epoch 248/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0268
# Epoch 249/250
# 42/42 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 250/250
# 42/42 [==============================] - 0s 1ms/step - loss: 0.0267

# %%
# View training history
plt.plot(history.history['loss'])

# %%
# Test model
eval_predictions = flat_list(model.predict(eval_predictors))

# %%
# Analyse model quality vs mean 
rmse = np.sqrt(np.mean((eval_targets.values - eval_predictions)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));

avg = np.mean(train_targets)

rmse = np.sqrt(np.mean((eval_targets.values - avg)**2))
print('Using the training data mean of {0} would have has resulted in a RMSE of {1}'.format(avg, rmse));
# Out:
# LinearRegression has RMSE of 0.16666502237429337
# Using the training data mean of 0.6636040419161677 would have has resulted in a RMSE of 0.1862504084616732

# %%
# Testing

test = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/{0}/test_set_district{0}.0.csv'.format(district))
test_predictors = test[columns[0:qty_predictors]]
normalise_w_params(test_predictors, scale_params, columns[0:qty_predictors])

test_predictions = pd.DataFrame(flat_list(model.predict(test_predictors)), columns=['crime_count'])
denormalise(test_predictions, scale_params, ['crime_count'])
test_targets = test[columns[qty_predictors]]

results = pd.DataFrame()
results['predicted'] = test_predictions
results['actual'] = test_targets
results['error_squared'] = (results['predicted'] - results['actual']) ** 2
print(results)

print('The RMSE on the 5 test values is {}.'.format(np.sqrt(np.mean(results.error_squared))))
print()
# Out:
#    predicted  actual  error_squared
# 0  46.978333      49       4.087139
# 1  42.462227      41       2.138107
# 2  43.189270      45       3.278743
# 3  35.009632      24     121.211999
# 4  47.823215      41      46.556270
# The RMSE on the 5 test values is 5.954364090925455.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
