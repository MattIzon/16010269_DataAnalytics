# %% [markdown]
# <a href="https://colab.research.google.com/github/MattIzon/16010269_DataAnalytics/blob/main/LR/Districts/4/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model District 4
#
# Predictors:
# *   day_of_week
# *   max
# *   sndp
# *   snow_ice_pellets

# %%
# Set-up
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def normalise(df, column_list):
  # Normalises df columns in column_list returning a dictionary of column_name: (min_value, max_value) that can be used to recover the original values
  params = dict()

  for col in column_list:
    min = df[col].min()
    max = df[col].max()
    params[col] = (min, max)
    df[col] = (df[col] - min) / (max - min)

  return params


def normalise_w_params(df, params, column_list):
  # Normalises df columns using the provided params
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] - min) / (max - min)


def denormalise(df, params, column_list):
  # Uses the params dictionary produced during normalisation and a list of columns to recover their original values
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] * (max-min)) + min


def flat_list(nested_list):
  return [value for sublist in nested_list for value in sublist]

# %%
generic = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/4/generic_set_district4.0.csv')

# %% [markdown]
# Model Specific Code goes here

# %%
generic.corr()['crime_count']
# Out:
# index                   0.072357
# day_of_week            -0.042357
# district                     NaN
# crime_count             1.000000
# mo                      0.074429
# temp                    0.413102
# dewp                    0.389446
# slp                    -0.175260
# stp                     0.111137
# visib                   0.150874
# wdsp                   -0.147827
# mxpsd                  -0.082956
# gust                   -0.078752
# max                     0.413308
# min                     0.397587
# prcp                    0.009125
# sndp                   -0.235065
# fog                    -0.069285
# rain_drizzle            0.037739
# snow_ice_pellets       -0.256893
# hail                         NaN
# thunder                 0.085633
# tornado_funnel_cloud         NaN
# Name: crime_count, dtype: float64

# %%
columns = ['day_of_week', 'max', 'sndp', 'snow_ice_pellets', 'crime_count']
data = generic[columns]
scale_params = normalise(data, columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Seperate train / eval predictors / targets
qty_predictors = 4
qty_targets = 1
train_size = int(len(data)*0.8)

train_predictors = data.iloc[:train_size,0:qty_predictors]
train_targets = data.iloc[:train_size,qty_predictors]

eval_predictors = data.iloc[train_size:,0:qty_predictors]
eval_targets = data.iloc[train_size:,qty_predictors]

# %%
# Design model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(qty_targets, input_shape=[qty_predictors]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.01))

# %%
# View model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
history = model.fit(train_predictors, train_targets, epochs=250)
# Out:
# Epoch 1/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.4554
# Epoch 2/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0502
# Epoch 3/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0384
# Epoch 4/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0365
# Epoch 5/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0353
# Epoch 6/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 7/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 8/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 9/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 10/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 11/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 12/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 13/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 14/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 15/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 16/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 17/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 18/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 19/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 20/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 21/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 22/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 23/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 24/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 25/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 26/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 27/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 28/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 29/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 30/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 31/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 32/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 33/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 34/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 35/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 36/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 37/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 38/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 39/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 40/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 41/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 42/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 43/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 44/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 45/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 46/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 47/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 48/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 49/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 50/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 51/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 52/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 53/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 54/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 55/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 56/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 57/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 58/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 59/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 60/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 61/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 62/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 63/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 64/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 65/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 66/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 67/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 68/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 69/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 70/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 71/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 72/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 73/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 74/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 75/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 76/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 77/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 78/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 79/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 80/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 81/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 82/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 83/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 84/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 85/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 86/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 87/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0343
# Epoch 88/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 89/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 90/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 91/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 92/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 93/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 94/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 95/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 96/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 97/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 98/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 99/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 100/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 101/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 102/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 103/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 104/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0338
# Epoch 105/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 106/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0343
# Epoch 107/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 108/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 109/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 110/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 111/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 112/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 113/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 114/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 115/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 116/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 117/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 118/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 119/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 120/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 121/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 122/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 123/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 124/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 125/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 126/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 127/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 128/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 129/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 130/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 131/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 132/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 133/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 134/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 135/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 136/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 137/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 138/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 139/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 140/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 141/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 142/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 143/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 144/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 145/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 146/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 147/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 148/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 149/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 150/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 151/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 152/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 153/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 154/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 155/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 156/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 157/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 158/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 159/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 160/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 161/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 162/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 163/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 164/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0347
# Epoch 165/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 166/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 167/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 168/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 169/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 170/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 171/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 172/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 173/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 174/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0349
# Epoch 175/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 176/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 177/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 178/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 179/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 180/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 181/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 182/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 183/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 184/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 185/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 186/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 187/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 188/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 189/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 190/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 191/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 192/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 193/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 194/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 195/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 196/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 197/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 198/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 199/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 200/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 201/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 202/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 203/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 204/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0342
# Epoch 205/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 206/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 207/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 208/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 209/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 210/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 211/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 212/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 213/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 214/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 215/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 216/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 217/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 218/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 219/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 220/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 221/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 222/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 223/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 224/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 225/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0349
# Epoch 226/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 227/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 228/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0343
# Epoch 229/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 230/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 231/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 232/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 233/250
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 234/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 235/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 236/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 237/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0342
# Epoch 238/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0339
# Epoch 239/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0347
# Epoch 240/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0340
# Epoch 241/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 242/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 243/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 244/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 245/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 246/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 247/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0345
# Epoch 248/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0346
# Epoch 249/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343
# Epoch 250/250
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0343

# %%
# View training history
plt.plot(history.history['loss'])

# %%
# Test model
eval_predictions = flat_list(model.predict(eval_predictors))

# %%
# Analyse model quality vs mean 
rmse = np.sqrt(np.mean((eval_targets.values - eval_predictions)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));

avg = np.mean(train_targets)

rmse = np.sqrt(np.mean((eval_targets.values - avg)**2))
print('Using the training data mean of {0} would have has resulted in a RMSE of {1}'.format(avg, rmse));
# Out:
# LinearRegression has RMSE of 0.17026677348528885
# Using the training data mean of 0.551794681048912 would have has resulted in a RMSE of 0.19307631725848412

# %%
# Testing

test = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Districts/4/test_set_district4.0.csv')
test_predictors = test[columns[0:qty_predictors]]
normalise_w_params(test_predictors, scale_params, columns[0:qty_predictors])

test_predictions = pd.DataFrame(flat_list(model.predict(test_predictors)), columns=['crime_count'])
denormalise(test_predictions, scale_params, ['crime_count'])
test_targets = test[columns[qty_predictors]]

results = pd.DataFrame()
results['predicted'] = test_predictions
results['actual'] = test_targets
results['error_squared'] = (results['predicted'] - results['actual']) ** 2
print(results)

print('The RMSE on the 5 test values is {}.'.format(np.sqrt(np.mean(results.error_squared))))
print()
# Out:
#    predicted  actual  error_squared
# 0  41.410194      47      31.245927
# 1  41.810371      36      33.760416
# 2  41.297333      48      44.925748
# 3  35.247253      33       5.050148
# 4  42.464737      42       0.215980
# The RMSE on the 5 test values is 4.7999628936189485.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
