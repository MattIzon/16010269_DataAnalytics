# %% [markdown]
# <a href="https://colab.research.google.com/github/MattIzon/16010269_DataAnalytics/blob/main/LR/Normalised/Nov-Apr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression Model Nov - Apr
# Predictors:
# *   day_of_week
# *   temp
# *   slp
# *   sndp
# *   snow_ice_pellets

# %%
# Set-up
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

def normalise(df, column_list):
  # Normalises df columns in column_list returning a dictionary of column_name: (min_value, max_value) that can be used to recover the original values
  params = dict()

  for col in column_list:
    min = df[col].min()
    max = df[col].max()
    params[col] = (min, max)
    df[col] = (df[col] - min) / (max - min)

  return params


def normalise_w_params(df, params, column_list):
  # Normalises df columns using the provided params
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] - min) / (max - min)


def denormalise(df, params, column_list):
  # Uses the params dictionary produced during normalisation and a list of columns to recover their original values
  for col in column_list:
    min = params[col][0]
    max = params[col][1]
    df[col] = (df[col] * (max-min)) + min


def flat_list(nested_list):
  return [value for sublist in nested_list for value in sublist]

# %%
generic = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Normalised/generic_set.csv')

# %% [markdown]
# Model Specific Code goes here

# %%
generic = generic.loc[generic['mo'].isin([1,2,3,4,11,12])]
generic.corr()['crime_count']
# Out:
# index                   0.133492
# day_of_week             0.009665
# crime_count             1.000000
# mo                      0.138158
# temp                    0.478388
# dewp                    0.423497
# slp                    -0.261705
# stp                     0.109641
# visib                   0.066767
# wdsp                   -0.073979
# mxpsd                  -0.040127
# gust                   -0.037597
# max                     0.464877
# min                     0.454356
# prcp                   -0.023926
# sndp                   -0.319143
# fog                    -0.036260
# rain_drizzle            0.065953
# snow_ice_pellets       -0.285751
# hail                         NaN
# thunder                 0.070417
# tornado_funnel_cloud         NaN
# Name: crime_count, dtype: float64

# %%
columns = ['day_of_week', 'temp', 'slp', 'sndp', 'snow_ice_pellets', 'crime_count']

data = generic[columns]
scale_params = normalise(data, columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Seperate train / eval predictors / targets
qty_predictors = 5
qty_targets = 1
train_size = int(len(data)*0.8)

train_predictors = data.iloc[:train_size,0:qty_predictors]
train_targets = data.iloc[:train_size,qty_predictors]

eval_predictors = data.iloc[train_size:,0:qty_predictors]
eval_targets = data.iloc[train_size:,qty_predictors]

# %%
# Design model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(qty_targets, input_shape=[qty_predictors]))
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.01))

# %%
# View model
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
history = model.fit(train_predictors, train_targets, epochs=250)
# Out:
# Epoch 1/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0816
# Epoch 2/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0518
# Epoch 3/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0406
# Epoch 4/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 5/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0304
# Epoch 6/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 7/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 8/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 9/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0262
# Epoch 10/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 11/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 12/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 13/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 14/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 15/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0255
# Epoch 16/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 17/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 18/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 19/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0254
# Epoch 20/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0254
# Epoch 21/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 22/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 23/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 24/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 25/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 26/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 27/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 28/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 29/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 30/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 31/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 32/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0255
# Epoch 33/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 34/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 35/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 36/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 37/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 38/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 39/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 40/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 41/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 42/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 43/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 44/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 45/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 46/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 47/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 48/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0259
# Epoch 49/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 50/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 51/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 52/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 53/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 54/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 55/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0247
# Epoch 56/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 57/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 58/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 59/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0258
# Epoch 60/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 61/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 62/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 63/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 64/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 65/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 66/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 67/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 68/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 69/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 70/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 71/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 72/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 73/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 74/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 75/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 76/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 77/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 78/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 79/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 80/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 81/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 82/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 83/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 84/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 85/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 86/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 87/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0257
# Epoch 88/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 89/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 90/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 91/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 92/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 93/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 94/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 95/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 96/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 97/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 98/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 99/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 100/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 101/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 102/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 103/250
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0248
# Epoch 104/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 105/250
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0254
# Epoch 106/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 107/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 108/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 109/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 110/250
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0249
# Epoch 111/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 112/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 113/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 114/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 115/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 116/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 117/250
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0249
# Epoch 118/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 119/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 120/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 121/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 122/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 123/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 124/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 125/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 126/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 127/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 128/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 129/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 130/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 131/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 132/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 133/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 134/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 135/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 136/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 137/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 138/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 139/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 140/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 141/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 142/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 143/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 144/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 145/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 146/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 147/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0256
# Epoch 148/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 149/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 150/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 151/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 152/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 153/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 154/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 155/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 156/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 157/250
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250
# Epoch 158/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 159/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 160/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 161/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 162/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 163/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 164/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 165/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0247
# Epoch 166/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 167/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 168/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 169/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 170/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 171/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 172/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 173/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 174/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 175/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 176/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 177/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 178/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 179/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 180/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 181/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 182/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 183/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 184/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 185/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 186/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 187/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 188/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0254
# Epoch 189/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 190/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 191/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 192/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 193/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 194/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 195/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 196/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 197/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0254
# Epoch 198/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 199/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254
# Epoch 200/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 201/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 202/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 203/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 204/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 205/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 206/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 207/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 208/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 209/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 210/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 211/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 212/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 213/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 214/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 215/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 216/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 217/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 218/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 219/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 220/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 221/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 222/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 223/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 224/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 225/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 226/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 227/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 228/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0252
# Epoch 229/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 230/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 231/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 232/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 233/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0261
# Epoch 234/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 235/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 236/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 237/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0248
# Epoch 238/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 239/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 240/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 241/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249
# Epoch 242/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 243/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 244/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 245/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 246/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248
# Epoch 247/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 248/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0251
# Epoch 249/250
# 21/21 [==============================] - 0s 1ms/step - loss: 0.0249
# Epoch 250/250
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248

# %%
# View training history
plt.plot(history.history['loss'])

# %%
# Test model
eval_predictions = flat_list(model.predict(eval_predictors))

# %%
# Analyse model quality vs mean 
rmse = np.sqrt(np.mean((eval_targets.values - eval_predictions)**2))
print('LinearRegression has RMSE of {0}'.format(rmse));

avg = np.mean(train_targets)

rmse = np.sqrt(np.mean((eval_targets.values - avg)**2))
print('Using the training data mean of {0} would have has resulted in a RMSE of {1}'.format(avg, rmse));
# Out:
# LinearRegression has RMSE of 0.17456103790672123
# Using the training data mean of 0.4552065404475043 would have has resulted in a RMSE of 0.1884287108941939

# %%
# Testing
test = pd.read_csv('https://raw.githubusercontent.com/MattIzon/16010269_DataAnalytics/main/LR/Normalised/test_set.csv')
test_predictors = test[columns[0:qty_predictors]]
normalise_w_params(test_predictors, scale_params, columns[0:qty_predictors])

test_predictions = pd.DataFrame(flat_list(model.predict(test_predictors)), columns=['crime_count'])
denormalise(test_predictions, scale_params, ['crime_count'])
test_targets = test[columns[qty_predictors]]

results = pd.DataFrame()
results['predicted'] = test_predictions
results['actual'] = test_targets
results['error_squared'] = (results['predicted'] - results['actual']) ** 2
print(results)

print('The RMSE on the 5 test values is {}.'.format(np.sqrt(np.mean(results.error_squared))))
print()
# Out:
#     predicted  actual  error_squared
# 0  734.902344     726      79.251724
# 1  615.198364     626     116.675335
# 2  705.970276     732     677.546538
# 3  692.541992     735    1802.682427
# 4  750.419067     794    1899.297688
# The RMSE on the 5 test values is 30.250466812796343.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
